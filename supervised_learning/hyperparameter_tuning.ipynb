# %% [markdown]
# ### CROSS VALIDATION RECAP

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import KFold,StratifiedKFold,train_test_split
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,classification_report
import pandas as pd
import numpy as np

# %%
X = load_breast_cancer(as_frame=True)['data']
y = load_breast_cancer()['target']

# %%
# initialize kfold object

kfold = KFold(n_splits= 5, random_state= 23, shuffle= True)

# init stratified kfold object
s_fold = StratifiedKFold(n_splits=5, random_state= 23, shuffle=True)

# %%
classifier = RandomForestClassifier(random_state= 23)
score = cross_val_score(estimator=classifier,X=X, y=y,
                        scoring='f1',n_jobs=1, verbose = 3,cv=s_fold.split(X, y))
# Out:
# [CV] END ................................ score: (test=0.978) total time=   0.6s
# [CV] END ................................ score: (test=0.966) total time=   0.7s
# [CV] END ................................ score: (test=0.959) total time=   0.5s
# [CV] END ................................ score: (test=0.979) total time=   0.9s
# [CV] END ................................ score: (test=0.972) total time=   0.8s

# %%
score
# Out:
# array([0.93617021, 0.95890411, 0.99300699, 0.97931034, 0.98571429])

# %% [markdown]
# ### HYPER-PARAMETER TUNING/OPTIMIZATION
#
# 1. GridSearch
# 2. Randomized Search
# 3. Bayesian Optimization

# %%
# create a function

def train_evaluate(X, y, **params):
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,
                                                        random_state=23, stratify=y)
    model = RandomForestClassifier(**params)
    model.fit(X_train, y_train)
    test_preds = model.predict(X_test)
    test_score = f1_score(y_test, test_preds)
    train_preds = model.predict(X_train)
    train_score = f1_score(y_train, train_preds)
    
    return test_score, train_score


train_evaluate(X=X, y=y, n_estimators= 20, max_depth = 5, random_state = 23)
# Out:
# (0.950354609929078, 0.9982486865148862)

# %%
n_estimators = [10,15,20,25,30]
max_depth = [2,4,6,8]

score_params = {}
for estimator in n_estimators:
    for depth in max_depth:
        test_score, train_score = train_evaluate(X=X, y=y, 
                                                 n_estimators = estimator,
                                                 max_depth = depth)
        score_params.update({test_score:f'n_estimator:{estimator}, max_depth:{depth}'})
        print(f'for estimator:{estimator}, max_depth: {depth}...train:{train_score},test_score:{test_score}')

score_params[max(list(score_params.keys()))]
# Out:
# for estimator:10, max_depth: 2...train:0.9651567944250871,test_score:0.9444444444444444
# for estimator:10, max_depth: 4...train:0.9912739965095986,test_score:0.9726027397260274
# for estimator:10, max_depth: 6...train:0.9982425307557118,test_score:0.951048951048951
# for estimator:10, max_depth: 8...train:0.9982425307557118,test_score:0.9361702127659575
# for estimator:15, max_depth: 2...train:0.96875,test_score:0.9523809523809523
# for estimator:15, max_depth: 4...train:0.9895104895104895,test_score:0.951048951048951
# for estimator:15, max_depth: 6...train:1.0,test_score:0.9655172413793104
# for estimator:15, max_depth: 8...train:1.0,test_score:0.9655172413793104
# for estimator:20, max_depth: 2...train:0.9722222222222222,test_score:0.9655172413793104
# for estimator:20, max_depth: 4...train:0.993006993006993,test_score:0.951048951048951
# for estimator:20, max_depth: 6...train:0.9982425307557118,test_score:0.9863013698630136
# for estimator:20, max_depth: 8...train:0.9982486865148862,test_score:0.9659863945578231
# for estimator:25, max_depth: 2...train:0.972027972027972,test_score:0.9583333333333334
# for estimator:25, max_depth: 4...train:0.9965034965034965,test_score:0.958904109589041
# for estimator:25, max_depth: 6...train:0.9964912280701754,test_score:0.958904109589041
# for estimator:25, max_depth: 8...train:1.0,test_score:0.958904109589041
# for estimator:30, max_depth: 2...train:0.9670710571923743,test_score:0.9659863945578231
# for estimator:30, max_depth: 4...train:0.9930313588850174,test_score:0.9726027397260274
# for estimator:30, max_depth: 6...train:1.0,test_score:0.9655172413793104
# for estimator:30, max_depth: 8...train:1.0,test_score:0.9583333333333334
# 'n_estimator:20, max_depth:6'

# %%
score_params[0.9659863945578231]
# Out:
# 'n_estimator:25, max_depth:8'

# %% [markdown]
# ### GRID SEARCH

# %%
# init the model 
classifier = RandomForestClassifier(random_state=23)

# init the kfold object
s_fold = StratifiedKFold(n_splits=5, random_state= 23, shuffle=True)

params = {
    'n_estimators': list(range(10,100, 10)),
    'max_depth': list(range(2,11, 2)),
    'criterion': ['gini','entropy']
}

model = GridSearchCV(estimator=classifier, param_grid=params,
                     scoring='f1',n_jobs=1,cv = s_fold.split(X,y),verbose=3,
                     return_train_score=True)

model.fit(X=X, y=y)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=10;, score=(train=0.962, test=0.964) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=10;, score=(train=0.964, test=0.945) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=10;, score=(train=0.965, test=0.940) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=10;, score=(train=0.964, test=0.951) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=10;, score=(train=0.964, test=0.958) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=20;, score=(train=0.961, test=0.978) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=20;, score=(train=0.971, test=0.952) total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=20;, score=(train=0.976, test=0.947) total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=20;, score=(train=0.967, test=0.952) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=20;, score=(train=0.974, test=0.965) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=30;, score=(train=0.964, test=0.978) total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=30;, score=(train=0.978, test=0.966) total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=30;, score=(train=0.976, test=0.940) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=30;, score=(train=0.966, test=0.966) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=30;, score=(train=0.978, test=0.958) total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=40;, score=(train=0.964, test=0.978) total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=40;, score=(train=0.978, test=0.966) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=40;, score=(train=0.976, test=0.932) total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=40;, score=(train=0.969, test=0.953) total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=40;, score=(train=0.978, test=0.951) total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=50;, score=(train=0.966, test=0.978) total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=50;, score=(train=0.978, test=0.958) total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=50;, score=(train=0.977, test=0.939) total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=50;, score=(train=0.970, test=0.966) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=50;, score=(train=0.976, test=0.951) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=60;, score=(train=0.966, test=0.978) total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=60;, score=(train=0.978, test=0.966) total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=60;, score=(train=0.977, test=0.939) total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=60;, score=(train=0.971, test=0.959) total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=60;, score=(train=0.976, test=0.951) total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=70;, score=(train=0.966, test=0.978) total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=70;, score=(train=0.976, test=0.959) total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=70;, score=(train=0.977, test=0.939) total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=70;, score=(train=0.972, test=0.959) total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=70;, score=(train=0.976, test=0.951) total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=80;, score=(train=0.964, test=0.978) total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=80;, score=(train=0.972, test=0.952) total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=80;, score=(train=0.976, test=0.939) total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=80;, score=(train=0.972, test=0.959) total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=80;, score=(train=0.976, test=0.951) total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=90;, score=(train=0.965, test=0.978) total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=90;, score=(train=0.972, test=0.959) total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=90;, score=(train=0.976, test=0.926) total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=90;, score=(train=0.970, test=0.959) total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=90;, score=(train=0.976, test=0.951) total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=10;, score=(train=0.986, test=0.986) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=10;, score=(train=0.985, test=0.966) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=10;, score=(train=0.988, test=0.940) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=10;, score=(train=0.990, test=0.944) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=10;, score=(train=0.990, test=0.965) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=20;, score=(train=0.993, test=0.978) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=20;, score=(train=0.991, test=0.959) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=20;, score=(train=0.988, test=0.947) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=20;, score=(train=0.993, test=0.958) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=20;, score=(train=0.991, test=0.965) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=30;, score=(train=0.991, test=0.986) total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=30;, score=(train=0.991, test=0.966) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=30;, score=(train=0.990, test=0.940) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=30;, score=(train=0.991, test=0.958) total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=30;, score=(train=0.993, test=0.958) total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=40;, score=(train=0.991, test=0.978) total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=40;, score=(train=0.995, test=0.966) total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=40;, score=(train=0.990, test=0.940) total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=40;, score=(train=0.993, test=0.973) total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=40;, score=(train=0.993, test=0.972) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=50;, score=(train=0.991, test=0.978) total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=50;, score=(train=0.993, test=0.966) total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=50;, score=(train=0.990, test=0.946) total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=50;, score=(train=0.993, test=0.973) total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=50;, score=(train=0.993, test=0.972) total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=60;, score=(train=0.991, test=0.978) total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=60;, score=(train=0.993, test=0.966) total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=60;, score=(train=0.991, test=0.946) total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=60;, score=(train=0.993, test=0.966) total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=60;, score=(train=0.991, test=0.965) total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=70;, score=(train=0.991, test=0.986) total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=70;, score=(train=0.993, test=0.966) total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=70;, score=(train=0.991, test=0.953) total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=70;, score=(train=0.991, test=0.966) total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=70;, score=(train=0.991, test=0.972) total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=80;, score=(train=0.991, test=0.986) total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=80;, score=(train=0.993, test=0.958) total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=80;, score=(train=0.991, test=0.939) total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=80;, score=(train=0.991, test=0.966) total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=80;, score=(train=0.991, test=0.972) total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=90;, score=(train=0.990, test=0.986) total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=90;, score=(train=0.995, test=0.966) total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=90;, score=(train=0.991, test=0.953) total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=90;, score=(train=0.991, test=0.966) total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=90;, score=(train=0.991, test=0.972) total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=10;, score=(train=0.993, test=0.971) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=10;, score=(train=0.997, test=0.979) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=10;, score=(train=1.000, test=0.952) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=10;, score=(train=0.997, test=0.972) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=10;, score=(train=1.000, test=0.965) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=20;, score=(train=0.995, test=0.978) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=20;, score=(train=0.998, test=0.973) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=20;, score=(train=0.998, test=0.946) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=20;, score=(train=0.997, test=0.966) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=20;, score=(train=0.997, test=0.965) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=30;, score=(train=0.995, test=0.978) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=30;, score=(train=0.998, test=0.959) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=30;, score=(train=0.998, test=0.946) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=30;, score=(train=0.995, test=0.973) total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=30;, score=(train=0.998, test=0.972) total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=40;, score=(train=0.995, test=0.978) total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=40;, score=(train=0.998, test=0.959) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=40;, score=(train=1.000, test=0.946) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=40;, score=(train=0.997, test=0.966) total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=40;, score=(train=0.998, test=0.972) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=50;, score=(train=0.995, test=0.986) total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=50;, score=(train=0.998, test=0.959) total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=50;, score=(train=1.000, test=0.946) total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=50;, score=(train=0.997, test=0.973) total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=50;, score=(train=0.998, test=0.979) total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=60;, score=(train=0.995, test=0.986) total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=60;, score=(train=0.998, test=0.959) total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=60;, score=(train=1.000, test=0.945) total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=60;, score=(train=0.997, test=0.973) total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=60;, score=(train=0.998, test=0.972) total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=70;, score=(train=0.995, test=0.986) total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=70;, score=(train=0.998, test=0.959) total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=70;, score=(train=1.000, test=0.945) total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=70;, score=(train=0.997, test=0.973) total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=70;, score=(train=0.998, test=0.972) total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=80;, score=(train=0.995, test=0.986) total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=80;, score=(train=0.998, test=0.966) total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=80;, score=(train=1.000, test=0.945) total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=80;, score=(train=0.997, test=0.979) total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=80;, score=(train=0.998, test=0.972) total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=90;, score=(train=0.995, test=0.986) total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=90;, score=(train=0.998, test=0.959) total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=90;, score=(train=1.000, test=0.952) total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=90;, score=(train=0.997, test=0.979) total time=   0.8s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=90;, score=(train=0.998, test=0.972) total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=10;, score=(train=0.998, test=0.978) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=10;, score=(train=0.997, test=0.958) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=10;, score=(train=1.000, test=0.959) total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=10;, score=(train=1.000, test=0.958) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=10;, score=(train=1.000, test=0.958) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=20;, score=(train=1.000, test=0.993) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=20;, score=(train=0.998, test=0.966) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=20;, score=(train=1.000, test=0.953) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=20;, score=(train=0.998, test=0.958) total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=20;, score=(train=1.000, test=0.965) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=30;, score=(train=1.000, test=0.993) total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=30;, score=(train=0.998, test=0.959) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=30;, score=(train=1.000, test=0.953) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=30;, score=(train=0.998, test=0.966) total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=30;, score=(train=1.000, test=0.979) total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=40;, score=(train=1.000, test=0.993) total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=40;, score=(train=0.998, test=0.966) total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=40;, score=(train=1.000, test=0.966) total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=40;, score=(train=1.000, test=0.966) total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=40;, score=(train=1.000, test=0.972) total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.986) total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=50;, score=(train=0.998, test=0.959) total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.959) total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.966) total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=60;, score=(train=1.000, test=0.978) total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=60;, score=(train=1.000, test=0.966) total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=60;, score=(train=1.000, test=0.953) total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=60;, score=(train=1.000, test=0.966) total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=60;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=70;, score=(train=1.000, test=0.978) total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=70;, score=(train=1.000, test=0.959) total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=70;, score=(train=1.000, test=0.959) total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=70;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=70;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=80;, score=(train=1.000, test=0.986) total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=80;, score=(train=1.000, test=0.966) total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=80;, score=(train=1.000, test=0.959) total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=80;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=80;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=90;, score=(train=1.000, test=0.978) total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=90;, score=(train=1.000, test=0.966) total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=90;, score=(train=1.000, test=0.966) total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=90;, score=(train=1.000, test=0.979) total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=90;, score=(train=1.000, test=0.972) total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=10;, score=(train=1.000, test=0.978) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=10;, score=(train=0.998, test=0.958) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=10;, score=(train=1.000, test=0.959) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=10;, score=(train=1.000, test=0.965) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=10;, score=(train=1.000, test=0.958) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=20;, score=(train=1.000, test=0.993) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=20;, score=(train=1.000, test=0.966) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=20;, score=(train=1.000, test=0.953) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=20;, score=(train=1.000, test=0.958) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=20;, score=(train=1.000, test=0.965) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=30;, score=(train=1.000, test=0.993) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=30;, score=(train=1.000, test=0.959) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=30;, score=(train=1.000, test=0.953) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=30;, score=(train=1.000, test=0.958) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=30;, score=(train=1.000, test=0.979) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.978) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.959) total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.966) total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.966) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.978) total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.959) total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.966) total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.966) total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.979) total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=60;, score=(train=1.000, test=0.978) total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=60;, score=(train=1.000, test=0.966) total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=60;, score=(train=1.000, test=0.953) total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=60;, score=(train=1.000, test=0.972) total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=60;, score=(train=1.000, test=0.972) total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=70;, score=(train=1.000, test=0.978) total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=70;, score=(train=1.000, test=0.959) total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=70;, score=(train=1.000, test=0.953) total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=70;, score=(train=1.000, test=0.965) total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=70;, score=(train=1.000, test=0.979) total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=80;, score=(train=1.000, test=0.978) total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=80;, score=(train=1.000, test=0.966) total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=80;, score=(train=1.000, test=0.953) total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=80;, score=(train=1.000, test=0.979) total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=80;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=90;, score=(train=1.000, test=0.978) total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=90;, score=(train=1.000, test=0.966) total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=90;, score=(train=1.000, test=0.959) total time=   1.3s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=90;, score=(train=1.000, test=0.979) total time=   1.6s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=90;, score=(train=1.000, test=0.972) total time=   0.9s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=10;, score=(train=0.966, test=0.957) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=10;, score=(train=0.966, test=0.952) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=10;, score=(train=0.964, test=0.933) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=10;, score=(train=0.970, test=0.937) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=10;, score=(train=0.965, test=0.965) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=20;, score=(train=0.964, test=0.978) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=20;, score=(train=0.964, test=0.952) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=20;, score=(train=0.972, test=0.940) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=20;, score=(train=0.964, test=0.946) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=20;, score=(train=0.971, test=0.958) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=30;, score=(train=0.962, test=0.978) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=30;, score=(train=0.969, test=0.959) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=30;, score=(train=0.971, test=0.940) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=30;, score=(train=0.967, test=0.952) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=30;, score=(train=0.971, test=0.958) total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=40;, score=(train=0.962, test=0.971) total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=40;, score=(train=0.971, test=0.966) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=40;, score=(train=0.969, test=0.920) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=40;, score=(train=0.962, test=0.952) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=40;, score=(train=0.972, test=0.958) total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=50;, score=(train=0.966, test=0.971) total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=50;, score=(train=0.969, test=0.966) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=50;, score=(train=0.971, test=0.926) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=50;, score=(train=0.965, test=0.952) total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=50;, score=(train=0.969, test=0.951) total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=60;, score=(train=0.962, test=0.978) total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=60;, score=(train=0.971, test=0.966) total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=60;, score=(train=0.971, test=0.920) total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=60;, score=(train=0.964, test=0.952) total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=60;, score=(train=0.973, test=0.951) total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=70;, score=(train=0.962, test=0.978) total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=70;, score=(train=0.973, test=0.959) total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=70;, score=(train=0.974, test=0.927) total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=70;, score=(train=0.963, test=0.952) total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=70;, score=(train=0.973, test=0.951) total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=80;, score=(train=0.966, test=0.971) total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=80;, score=(train=0.973, test=0.952) total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=80;, score=(train=0.971, test=0.927) total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=80;, score=(train=0.963, test=0.952) total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=80;, score=(train=0.973, test=0.958) total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=90;, score=(train=0.964, test=0.978) total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=90;, score=(train=0.973, test=0.952) total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=90;, score=(train=0.974, test=0.927) total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=90;, score=(train=0.965, test=0.952) total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=90;, score=(train=0.974, test=0.958) total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=4, n_estimators=10;, score=(train=0.985, test=0.993) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, n_estimators=10;, score=(train=0.991, test=0.966) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, n_estimators=10;, score=(train=0.993, test=0.940) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, n_estimators=10;, score=(train=0.991, test=0.958) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, n_estimators=10;, score=(train=0.993, test=0.972) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, n_estimators=20;, score=(train=0.991, test=0.993) total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=4, n_estimators=20;, score=(train=0.991, test=0.959) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=4, n_estimators=20;, score=(train=0.991, test=0.940) total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=4, n_estimators=20;, score=(train=0.990, test=0.972) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=4, n_estimators=20;, score=(train=0.991, test=0.965) total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=4, n_estimators=30;, score=(train=0.990, test=0.986) total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=4, n_estimators=30;, score=(train=0.993, test=0.959) total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=4, n_estimators=30;, score=(train=0.993, test=0.947) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=4, n_estimators=30;, score=(train=0.990, test=0.972) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=4, n_estimators=30;, score=(train=0.995, test=0.965) total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=4, n_estimators=40;, score=(train=0.991, test=0.986) total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=4, n_estimators=40;, score=(train=0.993, test=0.966) total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=4, n_estimators=40;, score=(train=0.995, test=0.953) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=4, n_estimators=40;, score=(train=0.990, test=0.972) total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=4, n_estimators=40;, score=(train=0.995, test=0.965) total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=4, n_estimators=50;, score=(train=0.991, test=0.993) total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=4, n_estimators=50;, score=(train=0.995, test=0.966) total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=4, n_estimators=50;, score=(train=0.995, test=0.953) total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=4, n_estimators=50;, score=(train=0.991, test=0.972) total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=4, n_estimators=50;, score=(train=0.995, test=0.965) total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=4, n_estimators=60;, score=(train=0.991, test=0.993) total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=4, n_estimators=60;, score=(train=0.995, test=0.966) total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=4, n_estimators=60;, score=(train=0.995, test=0.953) total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=4, n_estimators=60;, score=(train=0.991, test=0.972) total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=4, n_estimators=60;, score=(train=0.993, test=0.972) total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=4, n_estimators=70;, score=(train=0.991, test=0.993) total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=4, n_estimators=70;, score=(train=0.993, test=0.966) total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=4, n_estimators=70;, score=(train=0.995, test=0.953) total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=4, n_estimators=70;, score=(train=0.991, test=0.972) total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=4, n_estimators=70;, score=(train=0.993, test=0.972) total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=4, n_estimators=80;, score=(train=0.991, test=0.986) total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=4, n_estimators=80;, score=(train=0.995, test=0.958) total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=4, n_estimators=80;, score=(train=0.995, test=0.953) total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=4, n_estimators=80;, score=(train=0.991, test=0.972) total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=4, n_estimators=80;, score=(train=0.993, test=0.972) total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=4, n_estimators=90;, score=(train=0.991, test=0.993) total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=4, n_estimators=90;, score=(train=0.993, test=0.966) total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=4, n_estimators=90;, score=(train=0.995, test=0.953) total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=4, n_estimators=90;, score=(train=0.991, test=0.972) total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=4, n_estimators=90;, score=(train=0.993, test=0.972) total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=10;, score=(train=0.995, test=0.986) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=10;, score=(train=0.997, test=0.958) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=10;, score=(train=1.000, test=0.959) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=10;, score=(train=0.996, test=0.972) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=10;, score=(train=0.998, test=0.979) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=20;, score=(train=0.995, test=0.993) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=20;, score=(train=0.998, test=0.952) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=20;, score=(train=1.000, test=0.952) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=20;, score=(train=0.998, test=0.979) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=20;, score=(train=0.998, test=0.972) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=30;, score=(train=1.000, test=0.993) total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=30;, score=(train=0.998, test=0.952) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=30;, score=(train=1.000, test=0.959) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=30;, score=(train=0.998, test=0.979) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=30;, score=(train=1.000, test=0.972) total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=40;, score=(train=0.998, test=0.993) total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=40;, score=(train=0.998, test=0.952) total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=40;, score=(train=1.000, test=0.959) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=40;, score=(train=0.998, test=0.979) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=40;, score=(train=1.000, test=0.972) total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=50;, score=(train=0.998, test=0.986) total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=50;, score=(train=0.998, test=0.952) total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=50;, score=(train=1.000, test=0.953) total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=50;, score=(train=1.000, test=0.979) total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=50;, score=(train=1.000, test=0.979) total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=60;, score=(train=0.998, test=0.993) total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=60;, score=(train=0.998, test=0.952) total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=60;, score=(train=1.000, test=0.959) total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=60;, score=(train=1.000, test=0.973) total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=60;, score=(train=1.000, test=0.972) total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=70;, score=(train=1.000, test=0.993) total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=70;, score=(train=0.998, test=0.952) total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=70;, score=(train=1.000, test=0.953) total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=70;, score=(train=1.000, test=0.979) total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=70;, score=(train=1.000, test=0.979) total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=80;, score=(train=1.000, test=0.993) total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=80;, score=(train=0.998, test=0.958) total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=80;, score=(train=1.000, test=0.953) total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=80;, score=(train=1.000, test=0.979) total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=80;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=90;, score=(train=1.000, test=0.993) total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=90;, score=(train=0.998, test=0.958) total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=90;, score=(train=1.000, test=0.953) total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=90;, score=(train=1.000, test=0.979) total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=90;, score=(train=1.000, test=0.972) total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=10;, score=(train=0.998, test=0.986) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=10;, score=(train=1.000, test=0.966) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=10;, score=(train=0.998, test=0.944) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=10;, score=(train=1.000, test=0.958) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=10;, score=(train=1.000, test=0.971) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=20;, score=(train=1.000, test=0.978) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=20;, score=(train=1.000, test=0.959) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=20;, score=(train=1.000, test=0.952) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=20;, score=(train=0.998, test=0.979) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=20;, score=(train=1.000, test=0.972) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=30;, score=(train=1.000, test=0.978) total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=30;, score=(train=1.000, test=0.952) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=30;, score=(train=1.000, test=0.952) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=30;, score=(train=0.998, test=0.979) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=30;, score=(train=1.000, test=0.972) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=40;, score=(train=1.000, test=0.986) total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=40;, score=(train=1.000, test=0.952) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=40;, score=(train=1.000, test=0.959) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=40;, score=(train=1.000, test=0.979) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=40;, score=(train=1.000, test=0.972) total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.986) total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.952) total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.959) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.979) total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.972) total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=60;, score=(train=1.000, test=0.986) total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=60;, score=(train=1.000, test=0.952) total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=60;, score=(train=1.000, test=0.959) total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=60;, score=(train=1.000, test=0.979) total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=60;, score=(train=1.000, test=0.972) total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=70;, score=(train=1.000, test=0.993) total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=70;, score=(train=1.000, test=0.958) total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=70;, score=(train=1.000, test=0.959) total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=70;, score=(train=1.000, test=0.979) total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=70;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=80;, score=(train=1.000, test=0.993) total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=80;, score=(train=1.000, test=0.958) total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=80;, score=(train=1.000, test=0.953) total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=80;, score=(train=1.000, test=0.979) total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=80;, score=(train=1.000, test=0.972) total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=90;, score=(train=1.000, test=0.993) total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=90;, score=(train=1.000, test=0.966) total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=90;, score=(train=1.000, test=0.953) total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=90;, score=(train=1.000, test=0.979) total time=   0.9s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=90;, score=(train=1.000, test=0.972) total time=   1.0s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=10;, score=(train=0.998, test=0.986) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=10;, score=(train=1.000, test=0.966) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=10;, score=(train=0.998, test=0.944) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=10;, score=(train=1.000, test=0.958) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=10;, score=(train=1.000, test=0.978) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=20;, score=(train=1.000, test=0.978) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=20;, score=(train=1.000, test=0.959) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=20;, score=(train=1.000, test=0.952) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=20;, score=(train=0.998, test=0.979) total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=20;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=30;, score=(train=1.000, test=0.978) total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=30;, score=(train=1.000, test=0.952) total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=30;, score=(train=1.000, test=0.952) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=30;, score=(train=0.998, test=0.979) total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=30;, score=(train=1.000, test=0.972) total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.986) total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.952) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.959) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.979) total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.972) total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.986) total time=   1.0s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.952) total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.959) total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.979) total time=   0.9s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=60;, score=(train=1.000, test=0.986) total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=60;, score=(train=1.000, test=0.952) total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=60;, score=(train=1.000, test=0.959) total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=60;, score=(train=1.000, test=0.979) total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=60;, score=(train=1.000, test=0.972) total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=70;, score=(train=1.000, test=0.993) total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=70;, score=(train=1.000, test=0.958) total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=70;, score=(train=1.000, test=0.959) total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=70;, score=(train=1.000, test=0.979) total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=70;, score=(train=1.000, test=0.972) total time=   1.0s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=80;, score=(train=1.000, test=0.993) total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=80;, score=(train=1.000, test=0.958) total time=   1.1s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=80;, score=(train=1.000, test=0.953) total time=   1.5s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=80;, score=(train=1.000, test=0.979) total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=80;, score=(train=1.000, test=0.972) total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=90;, score=(train=1.000, test=0.993) total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=90;, score=(train=1.000, test=0.966) total time=   1.0s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=90;, score=(train=1.000, test=0.953) total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=90;, score=(train=1.000, test=0.979) total time=   0.9s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=90;, score=(train=1.000, test=0.972) total time=   0.6s
# GridSearchCV(cv=<generator object _BaseKFold.split at 0x000002452C41EDF0>,
#              estimator=RandomForestClassifier(random_state=23), n_jobs=1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'n_estimators': [10, 20, 30, 40, 50, 60, 70, 80, 90]},
#              return_train_score=True, scoring='f1', verbose=3)

# %%
model.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 8, 'n_estimators': 90}

# %%
model.best_score_
# Out:
# 0.9725173015538034

# %% [markdown]
# ### Random Search

# %%
# init the model 
classifier = RandomForestClassifier(random_state=23)

# init the kfold object
s_fold = StratifiedKFold(n_splits=5, random_state= 23, shuffle=True)

params = {
    'n_estimators': list(range(10,100, 10)),
    'max_depth': list(range(2,11, 2)),
    'criterion': ['gini','entropy']
}

model = RandomizedSearchCV(estimator=classifier,param_distributions=params,
                           n_iter=50,scoring='f1',n_jobs=1,random_state=23,
                           verbose=3, cv = s_fold.split(X,y))

model.fit(X=X, y=y)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=90;, score=0.986 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=90;, score=0.959 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=90;, score=0.952 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=90;, score=0.979 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=90;, score=0.972 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=20;, score=0.978 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=20;, score=0.952 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=20;, score=0.940 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=20;, score=0.946 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=20;, score=0.958 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, n_estimators=30;, score=0.986 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=4, n_estimators=30;, score=0.959 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=4, n_estimators=30;, score=0.947 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=4, n_estimators=30;, score=0.972 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=4, n_estimators=30;, score=0.965 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=40;, score=0.978 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=40;, score=0.966 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=40;, score=0.932 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=40;, score=0.953 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=40;, score=0.951 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=80;, score=0.993 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=80;, score=0.958 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=80;, score=0.953 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=80;, score=0.979 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=80;, score=0.972 total time=   1.0s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=10;, score=0.986 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=10;, score=0.966 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=10;, score=0.940 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=10;, score=0.944 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=10;, score=0.965 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=10;, score=0.986 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=10;, score=0.966 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=10;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=10;, score=0.958 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=10;, score=0.971 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=20;, score=0.993 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=20;, score=0.966 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=20;, score=0.953 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=20;, score=0.958 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=20;, score=0.965 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=70;, score=0.986 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=70;, score=0.959 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=70;, score=0.945 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=70;, score=0.973 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=70;, score=0.972 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=70;, score=0.993 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=70;, score=0.958 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=70;, score=0.959 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=70;, score=0.979 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=70;, score=0.972 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=70;, score=0.978 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=70;, score=0.959 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=70;, score=0.953 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=70;, score=0.965 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=70;, score=0.979 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=80;, score=0.993 total time=   1.3s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=80;, score=0.958 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=80;, score=0.953 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=80;, score=0.979 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=80;, score=0.972 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=10;, score=0.978 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=10;, score=0.958 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=10;, score=0.959 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=10;, score=0.958 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=10;, score=0.958 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=90;, score=0.978 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=90;, score=0.959 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=90;, score=0.926 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=90;, score=0.959 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=90;, score=0.951 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=4, n_estimators=50;, score=0.993 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=4, n_estimators=50;, score=0.966 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=4, n_estimators=50;, score=0.953 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=4, n_estimators=50;, score=0.972 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=4, n_estimators=50;, score=0.965 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=90;, score=0.986 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=90;, score=0.966 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=90;, score=0.953 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=90;, score=0.966 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=90;, score=0.972 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=50;, score=0.978 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=50;, score=0.958 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=50;, score=0.939 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=50;, score=0.966 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=50;, score=0.951 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=30;, score=0.993 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=30;, score=0.959 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=30;, score=0.953 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=30;, score=0.966 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=30;, score=0.979 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=60;, score=0.978 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=60;, score=0.966 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=60;, score=0.939 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=60;, score=0.959 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=60;, score=0.951 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=30;, score=0.993 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=30;, score=0.952 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=30;, score=0.959 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=30;, score=0.979 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=30;, score=0.972 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=80;, score=0.993 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=80;, score=0.958 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=80;, score=0.953 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=80;, score=0.979 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=80;, score=0.972 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=80;, score=0.978 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=80;, score=0.952 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=80;, score=0.939 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=80;, score=0.959 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=80;, score=0.951 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=60;, score=0.978 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=60;, score=0.966 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=60;, score=0.920 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=60;, score=0.952 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=60;, score=0.951 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=30;, score=0.986 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=30;, score=0.966 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=30;, score=0.940 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=30;, score=0.958 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=30;, score=0.958 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=30;, score=0.978 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=30;, score=0.959 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=30;, score=0.946 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=30;, score=0.973 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=30;, score=0.972 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=60;, score=0.986 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=60;, score=0.959 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=60;, score=0.945 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=60;, score=0.973 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=60;, score=0.972 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=60;, score=0.986 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=60;, score=0.952 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=60;, score=0.959 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=60;, score=0.979 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=60;, score=0.972 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=10;, score=0.971 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=10;, score=0.979 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=10;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=10;, score=0.972 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=10;, score=0.965 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=10;, score=0.986 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=10;, score=0.966 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=10;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=10;, score=0.958 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=10;, score=0.978 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=60;, score=0.986 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=60;, score=0.952 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=60;, score=0.959 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=60;, score=0.979 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=60;, score=0.972 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=80;, score=0.986 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=80;, score=0.958 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=80;, score=0.939 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=80;, score=0.966 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=80;, score=0.972 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=90;, score=0.978 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=90;, score=0.952 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=90;, score=0.927 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=90;, score=0.952 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=90;, score=0.958 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=4, n_estimators=80;, score=0.986 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=4, n_estimators=80;, score=0.958 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=4, n_estimators=80;, score=0.953 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=4, n_estimators=80;, score=0.972 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=4, n_estimators=80;, score=0.972 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=50;, score=0.986 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=50;, score=0.952 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=50;, score=0.953 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=50;, score=0.979 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=50;, score=0.979 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=30;, score=0.978 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=30;, score=0.952 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=30;, score=0.952 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=30;, score=0.979 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=30;, score=0.972 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=20;, score=0.993 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=20;, score=0.966 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=20;, score=0.953 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=20;, score=0.958 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=20;, score=0.965 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=80;, score=0.986 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=80;, score=0.966 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=80;, score=0.959 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=80;, score=0.972 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=80;, score=0.972 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=30;, score=0.978 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=30;, score=0.959 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=30;, score=0.940 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=30;, score=0.952 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=30;, score=0.958 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=90;, score=0.993 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=90;, score=0.966 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=90;, score=0.953 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=90;, score=0.979 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=90;, score=0.972 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=90;, score=0.993 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=90;, score=0.958 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=90;, score=0.953 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=90;, score=0.979 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=90;, score=0.972 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=10;, score=0.964 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=10;, score=0.945 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=10;, score=0.940 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=10;, score=0.951 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=10;, score=0.958 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=60;, score=0.978 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=60;, score=0.966 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=60;, score=0.946 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=60;, score=0.966 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=60;, score=0.965 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=40;, score=0.993 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=40;, score=0.966 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=40;, score=0.966 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=40;, score=0.966 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=40;, score=0.972 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=50;, score=0.986 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=50;, score=0.952 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=50;, score=0.959 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=50;, score=0.979 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=50;, score=0.972 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=30;, score=0.993 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=30;, score=0.959 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=30;, score=0.953 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=30;, score=0.958 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=30;, score=0.979 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=4, n_estimators=20;, score=0.993 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, n_estimators=20;, score=0.959 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=4, n_estimators=20;, score=0.940 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=4, n_estimators=20;, score=0.972 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=4, n_estimators=20;, score=0.965 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=50;, score=0.978 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=50;, score=0.966 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=50;, score=0.946 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=50;, score=0.973 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=50;, score=0.972 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=60;, score=0.978 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=60;, score=0.966 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=60;, score=0.953 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=60;, score=0.966 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=60;, score=0.972 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=90;, score=0.978 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=90;, score=0.966 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=90;, score=0.966 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=90;, score=0.979 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=90;, score=0.972 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=90;, score=0.978 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=90;, score=0.966 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=90;, score=0.959 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=90;, score=0.979 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=90;, score=0.972 total time=   0.5s
# RandomizedSearchCV(cv=<generator object _BaseKFold.split at 0x000001AB07CEEDF0>,
#                    estimator=RandomForestClassifier(random_state=23), n_iter=50,
#                    n_jobs=1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [2, 4, 6, 8, 10],
#                                         'n_estimators': [10, 20, 30, 40, 50, 60,
#                                                          70, 80, 90]},
#                    random_state=23, scoring='f1', verbose=3)
